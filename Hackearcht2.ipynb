# %%
# import required library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %%
#import dataset
train=pd.read_csv('C:\\Users\\KUMAR HIREMATH\\Documents\\dataset\\train.csv')
test=pd.read_csv('C:\\Users\\KUMAR HIREMATH\\Documents\\dataset\\test.csv')
sample=pd.read_csv('C:\\Users\\KUMAR HIREMATH\\Documents\\dataset\\sample_submission.csv')

# %%
train.head()
# Out:
#    Deal_title                      Lead_name               Industry  \
# 0  TitleM5DZY  Davis, Perkins and Bishop Inc            Restaurants
# 1  TitleKIW18                 Bender PLC LLC  Construction Services
# 2  TitleFXSDN          Carter-Henry and Sons      Hospitals/Clinics
# 3  TitlePSK4Y                 Garcia Ltd Ltd            Real Estate
# 4  Title904GV               Lee and Sons PLC     Financial Services
#
#   Deal_value Weighted_amount Date_of_creation      Pitch  \
# 0    320506$      2067263.7$       2020-03-29  Product_2
# 1     39488$       240876.8$       2019-07-10  Product_2
# 2    359392$      2407926.4$       2019-07-27  Product_1
# 3     76774$       468321.4$       2021-01-30  Product_2
# 4    483896$             NaN       2019-05-22  Product_2
#
#              Contact_no             Lead_revenue Fund_category  ...  \
# 0          607.447.7883         50 - 100 Million    Category 2  ...
# 1          892-938-9493  500 Million - 1 Billion    Category 4  ...
# ...

# %%
test.head()
# Out:
#    Deal_title                       Lead_name                   Industry  \
# 0  TitleAD16O                 Bonilla Ltd Inc  Investment Bank/Brokerage
# 1  TitleOW6CR  Williams, Rogers and Roach PLC                Electronics
# 2  TitleVVJQ5    Wood, Vaughn and Morales Ltd                      Banks
# 3  TitleUS8NA             Durham-Crawford Inc                      Music
# 4  Title5VGWW    Simpson, Duncan and Long LLC                Real Estate
#
#   Deal_value Weighted_amount Date_of_creation      Pitch  \
# 0    200988$             NaN       2020-04-15  Product_1
# 1    409961$      2541758.2$       2021-01-23  Product_1
# 2    434433$      3041031.0$       2020-07-19  Product_1
# 3    218952$      1521716.4$       2020-02-27  Product_2
# 4    392835$     2455218.75$       2020-10-25  Product_1
#
#               Contact_no             Lead_revenue Fund_category  ...  \
# 0       167.332.2751x989        100 - 500 Million    Category 4  ...
# ...

# %%
train.shape
# Out:
# (7007, 23)

# %%
test.shape
# Out:
# (2093, 22)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2093 entries, 0 to 2092
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Deal_title             2093 non-null   object
#  1   Lead_name              2093 non-null   object
#  2   Industry               2092 non-null   object
#  3   Deal_value             2093 non-null   int32
#  4   Weighted_amount        2033 non-null   object
#  5   Date_of_creation       2093 non-null   object
#  6   Pitch                  2093 non-null   object
#  7   Contact_no             2093 non-null   object
#  8   Lead_revenue           2093 non-null   object
#  9   Fund_category          2093 non-null   object
#  10  Geography              2014 non-null   object
#  11  Location               2090 non-null   object
#  12  POC_name               2091 non-null   object
#  13  Designation            2093 non-null   object
# ...

# %%
train['Deal_value'] = train['Deal_value'].str.replace('$','')
test['Deal_value'] = test['Deal_value'].str.replace('$','')

# %%
train['Deal_value'].fillna(train['Deal_value'].median(),inplace=True)
test['Deal_value'].fillna(test['Deal_value'].median(),inplace=True)

# %%
train['Deal_value'].isnull().sum()
test['Deal_value'].isnull().sum()
# Out:
# 0

# %%
train['Deal_value']=train['Deal_value'].astype(int)
test['Deal_value']=test['Deal_value'].astype(int)

# %%
train['Weighted_amount']=train['Weighted_amount'].str.replace('$','')
test['Weighted_amount']=test['Weighted_amount'].str.replace('$','')

# %%
train['Weighted_amount'].fillna(train['Weighted_amount'].median(),inplace=True)
test['Weighted_amount'].fillna(test['Weighted_amount'].median(),inplace=True)

# %%
train['Weighted_amount']=train['Weighted_amount'].astype(float)
test['Weighted_amount']=test['Weighted_amount'].astype(float)

# %%
train['creation_Year']=train['Date_of_creation'].str.split('-').str[0]
train['creation_month']=train['Date_of_creation'].str.split('-').str[1]
train['creation_date']=train['Date_of_creation'].str.split('-').str[2]

# %%
test['creation_Year']=test['Date_of_creation'].str.split('-').str[0]
test['creation_month']=test['Date_of_creation'].str.split('-').str[1]
test['creation_date']=test['Date_of_creation'].str.split('-').str[2]

# %%
train=train.drop(['Date_of_creation'],axis=1)

# %%
test=test.drop(['Date_of_creation'],axis=1)

# %%
train['Pitch'].unique()
# Out:
# array(['Product_2', 'Product_1'], dtype=object)

# %%
test['Pitch'].unique()
# Out:
# array(['Product_1', 'Product_2'], dtype=object)

# %%
train['Pitch']=pd.get_dummies(train['Pitch'])
test['Pitch']=pd.get_dummies(test['Pitch'])

# %%
train=train.drop(['Contact_no'],axis=1)
test=test.drop(['Contact_no'],axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
train['Lead_revenue']=encoder.fit_transform(train['Lead_revenue'])
test['Lead_revenue']=encoder.fit_transform(test['Lead_revenue'])

# %%
train['Fund_category'].unique()
# Out:
# array(['Category 2', 'Category 4', 'Category 3', 'Category 1'],
#       dtype=object)

# %%
train['Fund_category']=pd.get_dummies(train['Fund_category'],drop_first=True)
test['Fund_category']=pd.get_dummies(test['Fund_category'],drop_first=True)

# %%
train['Geography'].unique()
# Out:
# array(['USA', 'India', nan], dtype=object)

# %%
train['Geography']=train['Geography'].fillna('None')
test['Geography']=test['Geography'].fillna('None')

# %%
train['Geography']=pd.get_dummies(train['Geography'])
test['Geography']=pd.get_dummies(test['Geography'])

# %%
train['Location']=train['Location'].str.replace(',','')
test['Location']=test['Location'].str.replace(',','')

# %%
train['Location']=train['Location'].astype(str)
test['Location']=test['Location'].astype(str)

# %%
train['Location']=encoder.fit_transform(train['Location'])
test['Location']=encoder.fit_transform(test['Location'])

# %%
test=test.drop(['POC_name'],axis=1)

# %%
train['Designation']=encoder.fit_transform(train['Designation'])
test['Designation']=encoder.fit_transform(test['Designation'])

# %%
train=train.drop(['Lead_POC_email'],axis=1)
test=test.drop(['Lead_POC_email'],axis=1)

# %%
train['Hiring_candidate_role']=encoder.fit_transform(train['Hiring_candidate_role'])
test['Hiring_candidate_role']=encoder.fit_transform(test['Hiring_candidate_role'])

# %%
train['Lead_source']=pd.get_dummies(train['Lead_source'],drop_first=True)
test['Lead_source']=pd.get_dummies(test['Lead_source'],drop_first=True)

# %%
train['Level_of_meeting']=pd.get_dummies(train['Level_of_meeting'],drop_first=True)
test['Level_of_meeting']=pd.get_dummies(test['Level_of_meeting'],drop_first=True)

# %%
train['Last_lead_update'].fillna('None',inplace=True)

# %%
test['Last_lead_update'].fillna('None',inplace=True)

# %%
train['Last_lead_update']=encoder.fit_transform(train['Last_lead_update'])
test['Last_lead_update']=encoder.fit_transform(test['Last_lead_update'])

# %%
train=train.drop(['Internal_POC'],axis=1)
test=test.drop(['Internal_POC'],axis=1)

# %%
train['Resource'].unique()
# Out:
# array([nan, 'No', 'We have all the requirements', 'Deliverable',
#        'Cannot deliver', 'Not enough', 'Yes'], dtype=object)

# %%
train['Resource'].fillna('None',inplace=True)

# %%
test['Resource'].fillna('None',inplace=True)

# %%
train['Resource']=encoder.fit_transform(train['Resource'])
test['Resource']=encoder.fit_transform(test['Resource'])

# %%
train['Internal_rating'].isnull().sum()
# Out:
# 0

# %%
train['Success_probability'].median()
# Out:
# 65.3

# %%
train['Success_probability'].fillna(65.3,inplace=True)

# %%
train['Deal_title'].unique()
# Out:
# array(['TitleM5DZY', 'TitleKIW18', 'TitleFXSDN', ..., 'TitleF1FWY',
#        'TitleXVBNJ', 'TitleKXU3H'], dtype=object)

# %%
train['Deal_title']=encoder.fit_transform(train['Deal_title'])
test['Deal_title']=encoder.fit_transform(test['Deal_title'])

# %%
train=train.drop(['Lead_name'],axis=1)
test=test.drop(['Lead_name'],axis=1)

# %%
train['Industry']=train['Industry'].astype(str)
test['Industry']=test['Industry'].astype(str)

# %%
train['Industry']=encoder.fit_transform(train['Industry'])
test['Industry']=encoder.fit_transform(test['Industry'])

# %%
train['creation_Year']=train['creation_Year'].astype(int)
train['creation_month']=train['creation_month'].astype(int)
train['creation_date']=train['creation_date'].astype(int)

# %%
test['creation_month']=test['creation_month'].astype(int)
test['creation_date']=test['creation_date'].astype(int)
test['creation_Year']=test['creation_Year'].astype(int)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2093 entries, 0 to 2092
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Deal_title             2093 non-null   int32
#  1   Industry               2093 non-null   int32
#  2   Deal_value             2093 non-null   int32
#  3   Weighted_amount        2093 non-null   float64
#  4   Pitch                  2093 non-null   uint8
#  5   Lead_revenue           2093 non-null   int32
#  6   Fund_category          2093 non-null   uint8
#  7   Geography              2093 non-null   uint8
#  8   Location               2093 non-null   int32
#  9   Designation            2093 non-null   int32
#  10  Hiring_candidate_role  2093 non-null   int32
#  11  Lead_source            2093 non-null   uint8
#  12  Level_of_meeting       2093 non-null   uint8
#  13  Last_lead_update       2093 non-null   int32
#  14  Resource               2093 non-null   int32
# ...

# %%
corrmat=train.corr()
top_feat=corrmat.index
plt.figure(figsize=(20,20))
g=sns.heatmap(train[top_feat].corr(),annot=True,cmap='YlGnBu')

# %%
train=train.drop(['Geography'],axis=1)
test=test.drop(['Geography'],axis=1)

# %%
sns.pairplot(train)

# %%
from sklearn.model_selection import RandomizedSearchCV
n_estimators=[int(x) for x in np.linspace(start=100,stop=1200,num=12)]
max_features=['auto','sqrt']
max_depth=[int(x) for x in np.linspace(5,30,num=6)]
min_samples_split=[2,5,10,15,100]
min_samples_leaf=[1,2,5,10]

# %%
random_grid={'n_estimators':n_estimators,
            'max_features':max_features,
            'max_depth':max_depth,
            'min_samples_split':min_samples_split,
            'min_samples_leaf':min_samples_leaf}
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()

# %%
rf_random=RandomizedSearchCV(estimator=rf,param_distributions=random_grid,n_iter=10,cv=5,scoring='neg_mean_squared_error',verbose=2,random_state=42,n_jobs=1)

# %%
x=train.drop(['Success_probability'],axis=1)
y=train.Success_probability

# %%
rf_random.fit(x,y)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=  10.8s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.7s remaining:    0.0s
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=  10.9s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=  10.9s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# ...

# %%
rf_random.best_estimator_
# Out:
# RandomForestRegressor(max_depth=5, max_features='sqrt', min_samples_leaf=2,
#                       min_samples_split=10, n_estimators=700)

# %%
rf=RandomForestRegressor(max_depth=5, max_features='sqrt', min_samples_leaf=2,
                      min_samples_split=10, n_estimators=700)

# %%
rf.fit(x,y)
# Out:
# RandomForestRegressor(max_depth=5, max_features='sqrt', min_samples_leaf=2,
#                       min_samples_split=10, n_estimators=700)

# %%
y_pred=rf.predict(test)

# %%
from sklearn import metrics

# %%
sample.head()
# Out:
#    Deal_title  Success_probability
# 0  TitleM5DZY                 48.6
# 1  TitleKIW18                 33.9
# 2  TitleFXSDN                 43.8
# 3  TitlePSK4Y                 39.5
# 4  Title904GV                 37.4

# %%
sumbit=pd.DataFrame({'Deal_title':test.Deal_title,'Success_probability':y_pred})

# %%
sumbit.head()
# Out:
#    Deal_title  Success_probability
# 0         594            63.935851
# 1        1430            63.771009
# 2        1843            65.194425
# 3        1781            65.455141
# 4         332            63.606686

# %%
sumbit.to_csv('reduce_marketing_waste1.csv',index=False)
